# %% [markdown]
# ## Homework
#
# - 请用之前仿真过的数据，重新跑一次梯度下降的程序，给出迭代次数，学习率，精度
# - 用实用Boston房价来预测
#
# begin time：16：50；
# end time：17:33

# %% [markdown]
# ## homework1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib as mpl 
from matplotlib.font_manager import fontManager

fontManager.addfont("SIMSUN.TTC")
mpl.rc('font', family="SimSun")

def compute_cost(x,y,w,b):
    y_pre = w*x +b
    cost = (y-y_pre)**2
    cost = cost.sum() / len(x)
    return cost
def compute_gradient(x, y, w, b):
    w_gradient = (x*(w*x+b -y)).mean()
    b_gradient = (w*x+b -y).mean()
    return w_gradient, b_gradient
def gradient_descent(x, y, w_init, b_init, learning_rate, cost_function, gradient_function, run_iter, p_iter=1000):
  
    c_hist = []
    w_hist = []
    b_hist = []
    w = w_init
    b = b_init

    for i in range(run_iter):
        w_gradient, b_gradient = gradient_function(x, y, w, b)
    
        w = w - w_gradient*learning_rate
        b = b - b_gradient*learning_rate
        cost = cost_function(x, y, w, b)
    
        w_hist.append(w)
        b_hist.append(b)
        c_hist.append(cost)

        if i%p_iter == 0:
            print(f"Iteration {i:5} : Cost {cost: .4e}, w: {w: .2e}, b: {b: .2e}, w_gradient: {w_gradient: .2e}, b_gradient: {b_gradient: .2e}")
    return w, b, w_hist, b_hist, c_hist

## data 
X_data = np.arange(60)
Y_data = []
for i in X_data:
    y = 0.5*i+20
    n=np.random.uniform(-1,1)*2
    y = y+n
    Y_data.append(y)
    
w_init = 0
b_init = 0
learning_rate = 1.0e-3
run_iter = 40000

w_final, b_final, w_hist, b_hist, c_hist = gradient_descent(X_data, Y_data, w_init, b_init, learning_rate, compute_cost, compute_gradient, run_iter)
# Out:
# Iteration     0 : Cost  1.3723e+02, w:  1.17e+00, b:  3.47e-02, w_gradient: -1.17e+03, b_gradient: -3.47e+01
# Iteration  1000 : Cost  6.2237e+01, w:  8.87e-01, b:  4.53e+00, w_gradient:  9.95e-02, b_gradient: -3.95e+00
# Iteration  2000 : Cost  3.7851e+01, w:  8.00e-01, b:  8.01e+00, w_gradient:  7.70e-02, b_gradient: -3.05e+00
# Iteration  3000 : Cost  2.3243e+01, w:  7.32e-01, b:  1.07e+01, w_gradient:  5.96e-02, b_gradient: -2.36e+00
# Iteration  4000 : Cost  1.4491e+01, w:  6.79e-01, b:  1.28e+01, w_gradient:  4.61e-02, b_gradient: -1.83e+00
# Iteration  5000 : Cost  9.2474e+00, w:  6.38e-01, b:  1.44e+01, w_gradient:  3.57e-02, b_gradient: -1.42e+00
# Iteration  6000 : Cost  6.1062e+00, w:  6.07e-01, b:  1.57e+01, w_gradient:  2.76e-02, b_gradient: -1.10e+00
# Iteration  7000 : Cost  4.2244e+00, w:  5.83e-01, b:  1.66e+01, w_gradient:  2.14e-02, b_gradient: -8.49e-01
# Iteration  8000 : Cost  3.0970e+00, w:  5.64e-01, b:  1.74e+01, w_gradient:  1.66e-02, b_gradient: -6.57e-01
# Iteration  9000 : Cost  2.4216e+00, w:  5.49e-01, b:  1.79e+01, w_gradient:  1.28e-02, b_gradient: -5.08e-01
# Iteration 10000 : Cost  2.0170e+00, w:  5.38e-01, b:  1.84e+01, w_gradient:  9.92e-03, b_gradient: -3.94e-01
# Iteration 11000 : Cost  1.7746e+00, w:  5.29e-01, b:  1.87e+01, w_gradient:  7.68e-03, b_gradient: -3.05e-01
# Iteration 12000 : Cost  1.6293e+00, w:  5.22e-01, b:  1.90e+01, w_gradient:  5.94e-03, b_gradient: -2.36e-01
# Iteration 13000 : Cost  1.5423e+00, w:  5.17e-01, b:  1.92e+01, w_gradient:  4.60e-03, b_gradient: -1.82e-01
# Iteration 14000 : Cost  1.4902e+00, w:  5.13e-01, b:  1.94e+01, w_gradient:  3.56e-03, b_gradient: -1.41e-01
# Iteration 15000 : Cost  1.4590e+00, w:  5.10e-01, b:  1.95e+01, w_gradient:  2.76e-03, b_gradient: -1.09e-01
# Iteration 16000 : Cost  1.4403e+00, w:  5.07e-01, b:  1.96e+01, w_gradient:  2.13e-03, b_gradient: -8.46e-02
# Iteration 17000 : Cost  1.4291e+00, w:  5.05e-01, b:  1.97e+01, w_gradient:  1.65e-03, b_gradient: -6.55e-02
# Iteration 18000 : Cost  1.4224e+00, w:  5.04e-01, b:  1.97e+01, w_gradient:  1.28e-03, b_gradient: -5.07e-02
# Iteration 19000 : Cost  1.4183e+00, w:  5.03e-01, b:  1.98e+01, w_gradient:  9.89e-04, b_gradient: -3.92e-02
# Iteration 20000 : Cost  1.4159e+00, w:  5.02e-01, b:  1.98e+01, w_gradient:  7.66e-04, b_gradient: -3.04e-02
# Iteration 21000 : Cost  1.4145e+00, w:  5.01e-01, b:  1.98e+01, w_gradient:  5.93e-04, b_gradient: -2.35e-02
# Iteration 22000 : Cost  1.4136e+00, w:  5.01e-01, b:  1.99e+01, w_gradient:  4.59e-04, b_gradient: -1.82e-02
# Iteration 23000 : Cost  1.4131e+00, w:  5.00e-01, b:  1.99e+01, w_gradient:  3.55e-04, b_gradient: -1.41e-02
# Iteration 24000 : Cost  1.4128e+00, w:  5.00e-01, b:  1.99e+01, w_gradient:  2.75e-04, b_gradient: -1.09e-02
# Iteration 25000 : Cost  1.4126e+00, w:  5.00e-01, b:  1.99e+01, w_gradient:  2.13e-04, b_gradient: -8.44e-03
# Iteration 26000 : Cost  1.4125e+00, w:  5.00e-01, b:  1.99e+01, w_gradient:  1.65e-04, b_gradient: -6.53e-03
# Iteration 27000 : Cost  1.4124e+00, w:  5.00e-01, b:  1.99e+01, w_gradient:  1.27e-04, b_gradient: -5.05e-03
# Iteration 28000 : Cost  1.4124e+00, w:  4.99e-01, b:  1.99e+01, w_gradient:  9.86e-05, b_gradient: -3.91e-03
# Iteration 29000 : Cost  1.4124e+00, w:  4.99e-01, b:  1.99e+01, w_gradient:  7.63e-05, b_gradient: -3.03e-03
# Iteration 30000 : Cost  1.4124e+00, w:  4.99e-01, b:  1.99e+01, w_gradient:  5.91e-05, b_gradient: -2.34e-03
# Iteration 31000 : Cost  1.4123e+00, w:  4.99e-01, b:  1.99e+01, w_gradient:  4.57e-05, b_gradient: -1.81e-03
# Iteration 32000 : Cost  1.4123e+00, w:  4.99e-01, b:  1.99e+01, w_gradient:  3.54e-05, b_gradient: -1.40e-03
# Iteration 33000 : Cost  1.4123e+00, w:  4.99e-01, b:  1.99e+01, w_gradient:  2.74e-05, b_gradient: -1.09e-03
# Iteration 34000 : Cost  1.4123e+00, w:  4.99e-01, b:  1.99e+01, w_gradient:  2.12e-05, b_gradient: -8.41e-04
# Iteration 35000 : Cost  1.4123e+00, w:  4.99e-01, b:  1.99e+01, w_gradient:  1.64e-05, b_gradient: -6.51e-04
# Iteration 36000 : Cost  1.4123e+00, w:  4.99e-01, b:  1.99e+01, w_gradient:  1.27e-05, b_gradient: -5.04e-04
# Iteration 37000 : Cost  1.4123e+00, w:  4.99e-01, b:  1.99e+01, w_gradient:  9.83e-06, b_gradient: -3.90e-04
# Iteration 38000 : Cost  1.4123e+00, w:  4.99e-01, b:  1.99e+01, w_gradient:  7.61e-06, b_gradient: -3.02e-04
# Iteration 39000 : Cost  1.4123e+00, w:  4.99e-01, b:  1.99e+01, w_gradient:  5.89e-06, b_gradient: -2.34e-04

# %%
print(f"w，b=({w_final:.2f}, {b_final:.2f})；迭代次数为{run_iter};学习率为{learning_rate}")
print(f"w的精度为{1-abs(0.5-w_final)/0.5};b的精度为{1-abs(20-b_final)/20}")
# Out:
# w，b=(0.50, 19.93)；迭代次数为40000;学习率为0.001
# w的精度为0.9980887783268607;b的精度为0.9966261292034604

# %% [markdown]
# ## homework2  挨个参数线性预估？

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

def gradient_descent(x, y, w_init, b_init, learning_rate, cost_function, gradient_function, run_iter, p_iter=1000):
  
    c_hist = []
    w_hist = []
    b_hist = []
    w = w_init
    b = b_init

    for i in range(run_iter):
        w_gradient, b_gradient = gradient_function(x, y, w, b)
    
        w = w - w_gradient*learning_rate
        b = b - b_gradient*learning_rate
        cost = cost_function(x, y, w, b)
    
        w_hist.append(w)
        b_hist.append(b)
        c_hist.append(cost)

        # if i%p_iter == 0:
        #     print(f"Iteration {i:5} : Cost {cost: .4e}, w: {w: .2e}, b: {b: .2e}, w_gradient: {w_gradient: .2e}, b_gradient: {b_gradient: .2e}")
    return w, b, w_hist, b_hist, c_hist

df = pd.read_csv("boston.csv")
real = df.iloc[:,-1]

w_init = 0
b_init = 0
learning_rate = 1.0e-3
run_iter = 40000
    
for i in range(len(df.columns)-1):
    x = df.iloc[:,i]
    w_final, b_final, w_hist, b_hist, c_hist = gradient_descent(x, real, w_init, b_init, learning_rate, compute_cost, compute_gradient, run_iter)
    pre = w_final * x +b_final
    
    plt.scatter(x,real,marker="+",color="blue",alpha = 0.8,label="real")
    plt.plot(x,pre,color="red",alpha = 0.5,label="precise")
    plt.title(df.columns[i])
    plt.xlabel(df.columns[i])
    plt.ylabel('Price')
    plt.grid(color="grey",alpha=0.3,linestyle="--")
    plt.legend()
    plt.show()
    print(f"{df.columns[i]}的线性预估为：y={w_final}x+{b_final}")
# Out:
# CRIM的线性预估为：y=-0.4151902779150036x+24.033106174121784
# ZN的线性预估为：y=0.14213999415539155x+20.91757911779763
# INDUS的线性预估为：y=-0.6484558153889224x+29.754371643213812
# CHAS的线性预估为：y=5.984643192060493x+22.120560252457242
# NOX的线性预估为：y=-5.054163207610275x+25.17096801147314
# RM的线性预估为：y=5.678242844439385x+-12.89100423128314
# AGE的线性预估为：y=nanx+nan
# DIS的线性预估为：y=1.092038614842612x+18.3880022073521
# RAD的线性预估为：y=-0.4030953744011004x+26.382127993692556
# TAX的线性预估为：y=nanx+nan
# PIRATIO的线性预估为：y=-0.2178329936710186x+26.06290568629795
# B的线性预估为：y=nanx+nan
# LSTAT的线性预估为：y=-0.9499112058156975x+34.55153984115817

# %% [markdown]
# ##  简单线性回归

# %%
import pandas as pd

data = pd.read_csv("Salary_Data.csv")
# y = w*x + b
x = data["YearsExperience"]
y = data["Salary"]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  33 non-null     float64
#  1   Salary           33 non-null     float64
# dtypes: float64(2)
# memory usage: 660.0 bytes

# %%
data.describe()
# Out:
#        YearsExperience     Salary
# count        33.000000  33.000000
# mean          4.881818  18.137879
# std           3.036904   7.076154
# min           0.300000   9.050000
# 25%           2.900000  13.600000
# 50%           4.100000  15.800000
# 75%           7.100000  24.550000
# max          10.500000  30.575000

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl 
from matplotlib.font_manager import fontManager

fontManager.addfont("SIMSUN.TTC")
mpl.rc('font', family="SimSun")

plt.scatter(x, y, marker="^", color="purple")
plt.title("工作年限-工资")
plt.xlabel("年限")
plt.ylabel("收入（千元）")
plt.show()

# %% [markdown]
# ## Cost function(成本函数)   最优解

# %%
w = 10
b = 0

y_pre = w*x +b
cost = (y-y_pre)**2
cost.sum() / len(x)
# Out:
# 1476.1842424242425

# %%
type(y_pre)  ##序列
# Out:
# pandas.core.series.Series

# %%
def compute_cost(x,y,w,b):
    y_pre = w*x +b
    cost = (y-y_pre)**2
    cost = cost.sum() / len(x)
    return cost

# %%
import numpy as np
b=0
cost = []
for w in range(-100,101):
    cost.append(compute_cost(x,y,w,b))
W= range(-100,101)
print(min(cost))
plt.plot(W,cost)
plt.xlabel("w")
plt.ylabel("cost")
# Out:
# 18.84681818181818
# Text(0, 0.5, 'cost')

# %%
import numpy as np

ws = np.arange(-100, 101)
bs = np.arange(-100, 101)
costs = np.zeros((201, 201))


i=0
for w in  ws:
    j=0
    for b in bs:
        c = compute_cost(x,y,w,b)
        costs[i,j]= c
        j+=1
    i+=1
costs
# Out:
# array([[461185.0069697 , 459973.36757576, 458763.72818182, ...,
#         260286.4069697 , 259470.76757576, 258657.12818182],
#        [453468.4380303 , 452266.56227273, 451066.68651515, ...,
#         254503.0380303 , 253697.16227273, 252893.28651515],
#        [445817.42      , 444625.30787879, 443435.19575758, ...,
#         248785.22      , 247989.10787879, 247194.99575758],
#        ...,
#        [211743.7369697 , 212465.29757576, 213188.85818182, ...,
#         393618.7369697 , 394736.29757576, 395855.85818182],
#        [217006.2480303 , 217737.57227273, 218470.89651515, ...,
#         400814.4480303 , 401941.77227273, 403071.09651515],
#        [222334.31      , 223075.39787879, 223818.48575758, ...,
#         408075.71      , 409212.79787879, 410351.88575758]])

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl 
from matplotlib.font_manager import fontManager

fontManager.addfont("SIMSUN.TTC")
mpl.rc('font', family="SimSun")

plt.figure(figsize=(7, 7))
ax = plt.axes(projection="3d")
ax.view_init(40, 40)
ax.xaxis.set_pane_color((0, 0, 0))
ax.yaxis.set_pane_color((0, 0, 0))
ax.zaxis.set_pane_color((0, 0, 0))

b_grid, w_grid = np.meshgrid(bs, ws)
# https://wangyeming.github.io/2018/11/12/numpy-meshgrid/

ax.plot_surface(w_grid, b_grid, costs, cmap="Spectral_r", alpha=0.7)
ax.plot_wireframe(w_grid, b_grid, costs, color="black", alpha=0.1)

ax.set_title("w b 对应的 cost")
ax.set_xlabel("w")
ax.set_ylabel("b")
ax.set_zlabel("cost")

w_index, b_index = np.where(costs == np.min(costs))

ax.scatter(ws[w_index], bs[b_index], costs[w_index, b_index], color="red", s=40)

plt.show()

print(f"当w={ws[w_index]}, b={bs[b_index]} 会有最小的cost:{costs[w_index, b_index]}")
# Out:
# 当w=[2], b=[8] 会有最小的cost:[2.87151515]

# %% [markdown]
# ## Gradiant Descendent 梯度下降
#
# 永远沿着负方向更新参数（y&b）

# %% [markdown]
# #### 梯度函数

# %%
def compute_gradient(x, y, w, b):
  w_gradient = (x*(w*x+b -y)).mean()
  b_gradient = (w*x+b -y).mean()
  return w_gradient, b_gradient

# %%
def compute_gradient(x, y, w, b):
  w_gradient = (x*(w*x+b -y)).mean()
  b_gradient = (w*x+b -y).mean()
  return w_gradient, b_gradient

# %%
def gradient_descent(x, y, w_init, b_init, learning_rate, cost_function, gradient_function, run_iter, p_iter=1000):
  
  c_hist = []
  w_hist = []
  b_hist = []
  
  w = w_init
  b = b_init

  for i in range(run_iter):
    w_gradient, b_gradient = gradient_function(x, y, w, b)

    w = w - w_gradient*learning_rate
    b = b - b_gradient*learning_rate
    cost = cost_function(x, y, w, b)

    w_hist.append(w)
    b_hist.append(b)
    c_hist.append(cost)

    if i%p_iter == 0:
      print(f"Iteration {i:5} : Cost {cost: .4e}, w: {w: .2e}, b: {b: .2e}, w_gradient: {w_gradient: .2e}, b_gradient: {b_gradient: .2e}")

  return w, b, w_hist, b_hist, c_hist

# %%
w_init = 0
b_init = 0
learning_rate = 1.0e-3
run_iter = 40000

w_final, b_final, w_hist, b_hist, c_hist = gradient_descent(x, y, w_init, b_init, learning_rate, compute_cost, compute_gradient, run_iter)
# Out:
# Iteration     0 : Cost  3.8462e+05, w:  1.09e+02, b:  1.81e+01, w_gradient: -1.09e+02, b_gradient: -1.81e+01
# /tmp/ipykernel_2174941/987844602.py:13: RuntimeWarning: invalid value encountered in scalar subtract
#   w = w - w_gradient*learning_rate
# Iteration  1000 : Cost  0.0000e+00, w:  nan, b:  nan, w_gradient:  nan, b_gradient:  nan
# Iteration  2000 : Cost  0.0000e+00, w:  nan, b:  nan, w_gradient:  nan, b_gradient:  nan
# Iteration  3000 : Cost  0.0000e+00, w:  nan, b:  nan, w_gradient:  nan, b_gradient:  nan
# Iteration  4000 : Cost  0.0000e+00, w:  nan, b:  nan, w_gradient:  nan, b_gradient:  nan
# Iteration  5000 : Cost  0.0000e+00, w:  nan, b:  nan, w_gradient:  nan, b_gradient:  nan
# Iteration  6000 : Cost  0.0000e+00, w:  nan, b:  nan, w_gradient:  nan, b_gradient:  nan
# Iteration  7000 : Cost  0.0000e+00, w:  nan, b:  nan, w_gradient:  nan, b_gradient:  nan
# Iteration  8000 : Cost  0.0000e+00, w:  nan, b:  nan, w_gradient:  nan, b_gradient:  nan
# Iteration  9000 : Cost  0.0000e+00, w:  nan, b:  nan, w_gradient:  nan, b_gradient:  nan
# Iteration 10000 : Cost  0.0000e+00, w:  nan, b:  nan, w_gradient:  nan, b_gradient:  nan
# Iteration 11000 : Cost  0.0000e+00, w:  nan, b:  nan, w_gradient:  nan, b_gradient:  nan
# Iteration 12000 : Cost  0.0000e+00, w:  nan, b:  nan, w_gradient:  nan, b_gradient:  nan
# Iteration 13000 : Cost  0.0000e+00, w:  nan, b:  nan, w_gradient:  nan, b_gradient:  nan
# Iteration 14000 : Cost  0.0000e+00, w:  nan, b:  nan, w_gradient:  nan, b_gradient:  nan
# Iteration 15000 : Cost  0.0000e+00, w:  nan, b:  nan, w_gradient:  nan, b_gradient:  nan
# Iteration 16000 : Cost  0.0000e+00, w:  nan, b:  nan, w_gradient:  nan, b_gradient:  nan
# Iteration 17000 : Cost  0.0000e+00, w:  nan, b:  nan, w_gradient:  nan, b_gradient:  nan
# Iteration 18000 : Cost  0.0000e+00, w:  nan, b:  nan, w_gradient:  nan, b_gradient:  nan
# Iteration 19000 : Cost  0.0000e+00, w:  nan, b:  nan, w_gradient:  nan, b_gradient:  nan

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.plot(np.arange(0, 100), c_hist[:100])
plt.title("iteration vs cost")
plt.xlabel("iteration")
plt.ylabel("cost")
plt.show()

# %%
print(f"最终w b=({w_final:.2f}, {b_final:.2f})")
# Out:
# 最终w b=(2.28, 7.00)

# %%
import matplotlib as mpl 
from matplotlib.font_manager import fontManager

fontManager.addfont("SIMSUN.TTC")
mpl.rc('font', family="SimSun")

plt.figure(figsize=(7, 7))
ax = plt.axes(projection="3d")
ax.view_init(20, -65)
ax.xaxis.set_pane_color((0, 0, 0))
ax.yaxis.set_pane_color((0, 0, 0))
ax.zaxis.set_pane_color((0, 0, 0))

b_grid, w_grid = np.meshgrid(bs, ws)
# https://wangyeming.github.io/2018/11/12/numpy-meshgrid/

ax.plot_surface(w_grid, b_grid, costs, alpha=0.3)

ax.set_title("w b 对应的 cost")
ax.set_xlabel("w")
ax.set_ylabel("b")
ax.set_zlabel("cost")

w_index, b_index = np.where(costs == np.min(costs))
ax.scatter(ws[w_index], bs[b_index], costs[w_index, b_index], color="red", s=40)
ax.scatter(w_hist[0], b_hist[0], c_hist[0], color="green", s=40)
ax.plot(w_hist, b_hist, c_hist)

plt.show()
# Out:
# /mnt/storage-data2/conda_env/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) SimSun.
#   fig.canvas.print_figure(bytes_io, **kw)
# /mnt/storage-data2/conda_env/lib/python3.12/site-packages/mpl_toolkits/mplot3d/proj3d.py:177: RuntimeWarning: invalid value encountered in divide
#   txs, tys, tzs = vecw[0]/w, vecw[1]/w, vecw[2]/w
